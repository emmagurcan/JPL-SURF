# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray
import cartopy.crs as ccrs
import glob

#import the file as a dataset
file = 'dataset-duacs-nrt-global-merged-allsat-phy-l4_1588116812229.nc'
dataset = xarray.open_dataset(file)
print(dataset)

#extract variables
adt = dataset['adt']
lon = dataset['longitude']
lat = dataset['latitude']
time = dataset['time']
print(adt)
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 121, longitude: 161, time: 144)
# Coordinates:
#   * time       (time) datetime64[ns] 2019-08-10 2019-08-11 ... 2019-12-31
#   * latitude   (latitude) float32 20.12 20.38 20.62 20.88 ... 49.62 49.88 50.12
#   * longitude  (longitude) float32 -149.9 -149.6 -149.4 ... -110.4 -110.1 -109.9
# Data variables:
#     adt        (time, latitude, longitude) float64 ...
#     ugos       (time, latitude, longitude) float64 ...
#     vgos       (time, latitude, longitude) float64 ...
#     vgosa      (time, latitude, longitude) float64 ...
#     err        (time, latitude, longitude) float64 ...
#     err_vgosa  (time, latitude, longitude) float64 ...
#     err_ugosa  (time, latitude, longitude) float64 ...
#     sla        (time, latitude, longitude) float64 ...
#     ugosa      (time, latitude, longitude) float64 ...
# Attributes: (12/46)
#     _NCProperties:                   version=1|netcdflibversion=4.4.1.1|hdf5l...
# ...

# %%
#determine data from day 1
day_1 = adt[0, :, :]
print(day_1)
# Out:
# <xarray.DataArray 'adt' (latitude: 121, longitude: 161)>
# array([[1.1567, 1.1532, 1.132 , ..., 0.6698, 0.6691, 0.6717],
#        [1.168 , 1.16  , 1.1353, ..., 0.6403, 0.6494, 0.6631],
#        [1.1777, 1.1669, 1.1383, ..., 0.6192, 0.6324, 0.6479],
#        ...,
#        [0.4347, 0.4424, 0.4469, ...,    nan,    nan,    nan],
#        [0.427 , 0.4296, 0.4284, ...,    nan,    nan,    nan],
#        [0.4151, 0.4153, 0.4124, ...,    nan,    nan,    nan]])
# Coordinates:
#     time       datetime64[ns] 2019-08-10
#   * latitude   (latitude) float32 20.12 20.38 20.62 20.88 ... 49.62 49.88 50.12
#   * longitude  (longitude) float32 -149.9 -149.6 -149.4 ... -110.4 -110.1 -109.9
# Attributes:
#     comment:        The absolute dynamic topography is the sea surface height...
#     grid_mapping:   crs
#     long_name:      Absolute dynamic topography
#     standard_name:  sea_surface_height_above_geoid
#     units:          m
#     _ChunkSizes:    [ 1 50 50]

# %%
#set axis variables
x_min = -132
x_max = -118

y_min = 30
y_max = 42

#create plot
plt.figure()
fig, ax = plt.subplots(1)
cmap = plt.imshow(day_1, extent = [-130, -118, 30, 42], origin = 'lower', cmap = 'coolwarm')

#colorbar creation and scale
plt.colorbar()
plt.clim(0.4, 0.9)

#set a title
title = 'Absolute Dynamic Topograph (in meters) from Aviso on: 10-Aug-2019'
plt.title(title)

plt.show()
